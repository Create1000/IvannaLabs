# %% [markdown]
# Traveling in the summer 2023

# %%
name = input("please enter your name: ")
# Out:
# please enter your name: Ivanna

# %%
name
# Out:
# 'Ivanna'

# %% [markdown]
# ![reise%202023.jpg](attachment:reise%202023.jpg)

# %% [markdown]
# 1. Jogging
# 2. Reading
# 3. Sleeping
