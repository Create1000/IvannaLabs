# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df= pd.read_csv('cleaned_marketing_customer_analysis.csv')
df.head()
df
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %% [markdown]
# ### Get the numeric data into a dataframe called numerical and categorical columns in a dataframe called categorical. (You can use "np.number" and "object" to select the numerical data types and categorical data types respectively)

# %%
# Select numerical columns
numerical = df.select_dtypes(include=np.number)

# Select categorical columns
categorical = df.select_dtypes(include=object)

# %%
numerical
# Out:
#        Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
categorical
# Out:
#       Customer       State Response  Coverage Education Effective To Date  \
# 0      DK49336     Arizona       No     Basic   College        2011-02-18
# 1      KX64629  California       No     Basic   College        2011-01-18
# 2      LZ68649  Washington       No     Basic  Bachelor        2011-02-10
# 3      XL78013      Oregon      Yes  Extended   College        2011-01-11
# 4      QA50777      Oregon       No   Premium  Bachelor        2011-01-17
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor        2011-01-19
# 10906  KX53892      Oregon       No     Basic   College        2011-01-06
# 10907  TL39050     Arizona       No  Extended  Bachelor        2011-02-06
# 10908  WA60547  California       No   Premium   College        2011-02-13
# 10909  IV32877         NaN      NaN     Basic  Bachelor        2011-01-08
#
#       EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# ...

# %% [markdown]
# ### Now we will try to check the normality of the numerical variables visually
# - Use the Seaborn library to construct distribution plots for the numerical variables
# - Use the Matplotlib library to construct histograms.
# - Do the distributions for different numerical variables look like a normal distribution?

# %%
fig, axes = plt.subplots(nrows=len(numerical.columns), figsize=(8, 6 * len(numerical.columns)))

# Iterate over numerical columns and create distribution plots
for i, column in enumerate(numerical.columns):
    ax = axes[i]
    sns.histplot(data=numerical, x=column, kde=True, ax=ax)
    ax.set_title(f"Distribution of {column}")
    ax.set_xlabel(column)

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
sns.histplot(df["Customer Lifetime Value"], kde=True)

plt.show()

# %%
sns.histplot(df["Income"], kde=True)

plt.show()

# %%
sns.histplot(df["Monthly Premium Auto"], kde=True)

plt.show()

# %%
sns.histplot(df["Months Since Last Claim"], kde=True)

plt.show()

# %%
sns.histplot(df['Months Since Policy Inception'], kde=True)

plt.show()

# %%
sns.histplot(df["Number of Open Complaints"], kde=True)

plt.show()

# %%
sns.histplot(df["Number of Policies"], kde=True)

plt.show()

# %%
sns.histplot(df['Total Claim Amount'], kde=True)

plt.show()

# %%
plt.hist(df["Customer Lifetime Value"])
plt.show()

# %%
plt.hist(df["Income"])
plt.show()

# %%
plt.hist(df["Monthly Premium Auto"])
plt.show()

# %%
plt.hist(df["Months Since Last Claim"])
plt.show()

# %%
plt.hist(df['Months Since Policy Inception'])
plt.show()

# %%
plt.hist(df["Number of Open Complaints"])
plt.show()

# %%
plt.hist(df["Number of Policies"])
plt.show()

# %%
plt.hist(df['Total Claim Amount'])
plt.show()

# %%
sns.displot(
  data=df,
  x="Income",
  hue="State",
  kind="kde",
  height=6,
  aspect=1.4,
  log_scale=10
)
# Out:
# C:\Users\ivann\anaconda3\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\ivann\AppData\Local\Temp\ipykernel_812\896409574.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.displot(

# %% [markdown]
# ### Check for correlation between the input features

# %%
sns.scatterplot(data=numerical, x="Number of Open Complaints", y="Customer Lifetime Value")
# Out:
# <Axes: xlabel='Number of Open Complaints', ylabel='Customer Lifetime Value'>

# %%
sns.scatterplot(data=numerical, x='Customer Lifetime Value', y="Total Claim Amount")
# Out:
# <Axes: xlabel='Customer Lifetime Value', ylabel='Total Claim Amount'>

# %% [markdown]
# ### Plot the Correlation Heatmap

# %%
fig=plt.figure(figsize=(8,5))
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\ivann\AppData\Local\Temp\ipykernel_15188\2164872825.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >
