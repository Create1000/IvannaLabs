# %% [markdown]
# ### Lab | Data Aggregation and Filtering
# Objective: Use Python programming techniques to filter and order data subsets, group data by one or more variables, and use aggregation functions to obtain insights, and derive meaningful conclusions from the data.
#
# In this challenge, we will continue to work with customer data from an insurance company. We will use the dataset called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing first data cleaning, formatting, and structuring.
#
# Start by reading the dataset, standardizing column names, dealing with null values and creating the month column. You can do so by using the functions you developed in previous labs, or by reading the clean dataset you saved in the last lab data structuring and combining.
#
# Then, answer the following questions:
#
# 1. Create a new DataFrame that only includes customers who have a total_claim_amount greater than $1,000 and have a response of "Yes" to the last marketing campaign.
# 2. Analyze the average total_claim_amount by each policy type and gender for customers who have responded "Yes" to the last marketing campaign.
# 3. Analyze the total number of customers who have policies in each state, and then filter the results to only include states where there are more than 500 customers.
# 4. Find the median customer lifetime value by education level and gender.
# 5. Find the maximum, minimum, and average number of open complaints by state and policy type.
# 6. The marketing team wants to analyze the number of policies sold by state and month.
# Present the data in a table where the months are arranged as columns and the states are arranged as rows.
#
# 7. Display a new DataFrame that contains the number of policies sold by month by state for the top 3 states with the highest number of policies sold.
# Hint:
#
# To accomplish this, you will first need to group the data by state and month, then count the number of policies sold for each group. Afterwards, you will need to sort the data by the count of policies sold in descending order.
# Next, you will select the top 3 states with the highest number of policies sold.
# Finally, you will create a new DataFrame that contains the number of policies sold by month for each of the top 3 states.
#
#
# 8. The marketing team wants to analyze the effect of different marketing channels on the customer response rate.
# Hint: You can use melt to unpivot the data and create a table that shows the customer response rate (those who responded "Yes") by marketing channel.
#
# External Resources for Data Filtering: https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df= pd.read_csv('cleaned_marketing_customer_analysis.csv')
df.head()
df
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       Education Effective To Date EmploymentStatus Gender  Income  ...  \
# 0       College        2011-02-18         Employed      M   48029  ...
# 1       College        2011-01-18       Unemployed      F       0  ...
# 2      Bachelor        2011-02-10         Employed      M   22139  ...
# 3       College        2011-01-11         Employed      M   49078  ...
# 4      Bachelor        2011-01-17    Medical Leave      F   23675  ...
# ...         ...               ...              ...    ...     ...  ...
# 10905  Bachelor        2011-01-19       Unemployed      F       0  ...
# 10906   College        2011-01-06         Employed      F   61146  ...
# 10907  Bachelor        2011-02-06         Employed      F   39837  ...
# 10908   College        2011-02-13         Employed      F   64195  ...
# 10909  Bachelor        2011-01-08       Unemployed      M       0  ...
#
#       Number of Policies     Policy Type        Policy  Renew Offer Type  \
# 0                      9  Corporate Auto  Corporate L3            Offer3
# 1                      1   Personal Auto   Personal L3            Offer4
# 2                      2   Personal Auto   Personal L3            Offer3
# 3                      2  Corporate Auto  Corporate L3            Offer2
# 4                      7   Personal Auto   Personal L2            Offer1
# ...                  ...             ...           ...               ...
# 10905                  7   Personal Auto   Personal L1            Offer3
# 10906                  6   Personal Auto   Personal L3            Offer2
# 10907                  2  Corporate Auto  Corporate L3            Offer1
# 10908                  6   Personal Auto   Personal L1            Offer1
# 10909                  3   Personal Auto   Personal L1            Offer4
#
#        Sales Channel  Total Claim Amount  Vehicle Class Vehicle Size  \
# 0              Agent          292.800000  Four-Door Car      Medsize
# 1        Call Center          744.924331  Four-Door Car      Medsize
# 2        Call Center          480.000000            SUV      Medsize
# 3             Branch          484.013411  Four-Door Car      Medsize
# 4             Branch          707.925645  Four-Door Car      Medsize
# ...              ...                 ...            ...          ...
# 10905            Web         1214.400000     Luxury Car      Medsize
# 10906         Branch          273.018929  Four-Door Car      Medsize
# 10907            Web          381.306996     Luxury SUV      Medsize
# 10908         Branch          618.288849            SUV      Medsize
# 10909            Web         1021.719397            SUV      Medsize
#
#       Vehicle Type     Month
# 0              NaN  February
# 1              NaN   January
# 2                A  February
# 3                A   January
# 4              NaN   January
# ...            ...       ...
# 10905            A   January
# 10906            A   January
# 10907          NaN  February
# 10908            A  February
# 10909          NaN   January
#
# [10910 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       10910 non-null  object
#  1   State                          10279 non-null  object
#  2   Customer Lifetime Value        10910 non-null  float64
#  3   Response                       10279 non-null  object
#  4   Coverage                       10910 non-null  object
#  5   Education                      10910 non-null  object
#  6   Effective To Date              10910 non-null  object
#  7   EmploymentStatus               10910 non-null  object
#  8   Gender                         10910 non-null  object
#  9   Income                         10910 non-null  int64
#  10  Location Code                  10910 non-null  object
#  11  Marital Status                 10910 non-null  object
#  12  Monthly Premium Auto           10910 non-null  int64
#  13  Months Since Last Claim        10277 non-null  float64
#  14  Months Since Policy Inception  10910 non-null  int64
#  15  Number of Open Complaints      10277 non-null  float64
#  16  Number of Policies             10910 non-null  int64
#  17  Policy Type                    10910 non-null  object
#  18  Policy                         10910 non-null  object
#  19  Renew Offer Type               10910 non-null  object
#  20  Sales Channel                  10910 non-null  object
#  21  Total Claim Amount             10910 non-null  float64
#  22  Vehicle Class                  10288 non-null  object
#  23  Vehicle Size                   10288 non-null  object
#  24  Vehicle Type                   5428 non-null   object
#  25  Month                          10910 non-null  object
# dtypes: float64(4), int64(4), object(18)
# memory usage: 2.2+ MB

# %% [markdown]
# ### 1. Create a new DataFrame that only includes customers who have a total_claim_amount greater than $1,000 and have a response of "Yes" to the last marketing campaign.

#
# %%
df1=df[(df['Total Claim Amount'] > 1000) & (df['Response'] == 'Yes')]

# %%
df1
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 189    OK31456  California             11009.130490      Yes   Premium
# 236    YJ16163      Oregon             11009.130490      Yes   Premium
# 419    GW43195      Oregon             25807.063000      Yes  Extended
# 442    IP94270     Arizona             13736.132500      Yes   Premium
# 587    FJ28407  California              5619.689084      Yes   Premium
# ...        ...         ...                      ...      ...       ...
# 10351  FN44127      Oregon              3508.569533      Yes  Extended
# 10373  XZ64172      Oregon             10963.957230      Yes   Premium
# 10487  IX60941      Oregon              3508.569533      Yes  Extended
# 10565  QO62792      Oregon              7840.165778      Yes  Extended
# 10708  CK39096      Oregon              5619.689084      Yes   Premium
#
#                   Education Effective To Date EmploymentStatus Gender  Income  \
# 189                Bachelor        2011-01-24         Employed      F   51643
# 236                Bachelor        2011-01-24         Employed      F   51643
# 419                 College        2011-02-13         Employed      F   71210
# 442                  Master        2011-02-13         Disabled      F   16181
# 587    High School or Below        2011-01-26       Unemployed      M       0
# ...                     ...               ...              ...    ...     ...
# 10351               College        2011-01-05    Medical Leave      M   20978
# 10373  High School or Below        2011-02-08         Employed      M   55687
# 10487               College        2011-01-05    Medical Leave      M   20978
# 10565               College        2011-01-14         Employed      M   58414
# 10708  High School or Below        2011-01-26       Unemployed      M       0
#
#        ... Number of Policies     Policy Type        Policy  Renew Offer Type  \
# 189    ...                  1  Corporate Auto  Corporate L3            Offer2
# 236    ...                  1    Special Auto    Special L3            Offer2
# 419    ...                  2   Personal Auto   Personal L2            Offer1
# 442    ...                  8   Personal Auto   Personal L2            Offer1
# 587    ...                  1   Personal Auto   Personal L1            Offer2
# ...    ...                ...             ...           ...               ...
# 10351  ...                  1   Personal Auto   Personal L2            Offer2
# 10373  ...                  1  Corporate Auto  Corporate L2            Offer1
# 10487  ...                  1   Personal Auto   Personal L3            Offer2
# 10565  ...                  1   Personal Auto   Personal L3            Offer2
# 10708  ...                  1   Personal Auto   Personal L3            Offer2
#
#        Sales Channel  Total Claim Amount  Vehicle Class Vehicle Size  \
# 189            Agent         1358.400000     Luxury Car      Medsize
# 236            Agent         1358.400000     Luxury Car      Medsize
# 419           Branch         1027.200000     Luxury Car        Small
# 442              Web         1261.319869            SUV      Medsize
# 587              Web         1027.000029            SUV      Medsize
# ...              ...                 ...            ...          ...
# 10351         Branch         1176.278800  Four-Door Car        Small
# 10373          Agent         1324.800000     Luxury SUV      Medsize
# 10487         Branch         1176.278800  Four-Door Car        Small
# 10565          Agent         1008.000000            NaN          NaN
# 10708            Web         1027.000029            SUV      Medsize
#
#       Vehicle Type     Month
# 189            NaN   January
# 236              A   January
# 419              A  February
# 442              A  February
# 587              A   January
# ...            ...       ...
# 10351          NaN   January
# 10373          NaN  February
# 10487          NaN   January
# 10565          NaN   January
# 10708            A   January
#
# [67 rows x 26 columns]

# %% [markdown]
# ### 2. Analyze the average total_claim_amount by each policy type and gender for customers who have responded "Yes" to the last marketing campaign.

# %%
df2 = df[df['Response'] == 'Yes']
df2=df2.groupby(["Policy Type","Gender"])[["Total Claim Amount"]].mean()
df2
# Out:
#                        Total Claim Amount
# Policy Type    Gender
# Corporate Auto F               433.738499
#                M               408.582459
# Personal Auto  F               452.965929
#                M               457.010178
# Special Auto   F               453.280164
#                M               429.527942

# %% [markdown]
# ### 3. Analyze the total number of customers who have policies in each state, and then filter the results to only include states where there are more than 500 customers.

# %%
state_counts = df['State'].value_counts()
filtered_states = state_counts[state_counts > 500]
filtered_states
# Out:
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# Name: State, dtype: int64

# %%
df3 = df.groupby('State').size()
df3 = grouped [grouped > 500]
df3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 df3 = df.groupby('State').size()
# ----> 2 df3 = grouped [grouped > 500]
#       3 df3
#
# NameError: name 'grouped' is not defined

# %% [markdown]
# ### 4. Find the median customer lifetime value by education level and gender.

# %%
 df.groupby(['Education', 'Gender'])['Customer Lifetime Value'].median()
# Out:
# Education             Gender
# Bachelor              F         5640.505303
#                       M         5548.031892
# College               F         5623.611187
#                       M         6005.847375
# Doctor                F         5332.462694
#                       M         5577.669457
# High School or Below  F         6039.553187
#                       M         6286.731006
# Master                F         5729.855012
#                       M         5579.099207
# Name: Customer Lifetime Value, dtype: float64

# %% [markdown]
# ### 5. Find the maximum, minimum, and average number of open complaints by state and policy type.

# %%
 df.groupby(['State', 'Policy Type'])['Number of Open Complaints'].max()
# Out:
# State       Policy Type
# Arizona     Corporate Auto    5.0
#             Personal Auto     5.0
#             Special Auto      3.0
# California  Corporate Auto    4.0
#             Personal Auto     5.0
#             Special Auto      5.0
# Nevada      Corporate Auto    5.0
#             Personal Auto     5.0
#             Special Auto      5.0
# Oregon      Corporate Auto    4.0
#             Personal Auto     5.0
#             Special Auto      5.0
# Washington  Corporate Auto    5.0
#             Personal Auto     5.0
#             Special Auto      4.0
# Name: Number of Open Complaints, dtype: float64

# %%
 df.groupby(['State', 'Policy Type'])['Number of Open Complaints'].min()
# Out:
# State       Policy Type
# Arizona     Corporate Auto    0.0
#             Personal Auto     0.0
#             Special Auto      0.0
# California  Corporate Auto    0.0
#             Personal Auto     0.0
#             Special Auto      0.0
# Nevada      Corporate Auto    0.0
#             Personal Auto     0.0
#             Special Auto      0.0
# Oregon      Corporate Auto    0.0
#             Personal Auto     0.0
#             Special Auto      0.0
# Washington  Corporate Auto    0.0
#             Personal Auto     0.0
#             Special Auto      0.0
# Name: Number of Open Complaints, dtype: float64

# %%
 df.groupby(['State', 'Policy Type'])['Number of Open Complaints'].mean()
# Out:
# State       Policy Type
# Arizona     Corporate Auto    0.360795
#             Personal Auto     0.391021
#             Special Auto      0.246914
# California  Corporate Auto    0.307006
#             Personal Auto     0.401555
#             Special Auto      0.449153
# Nevada      Corporate Auto    0.463768
#             Personal Auto     0.406026
#             Special Auto      0.600000
# Oregon      Corporate Auto    0.339823
#             Personal Auto     0.371234
#             Special Auto      0.374046
# Washington  Corporate Auto    0.512048
#             Personal Auto     0.382445
#             Special Auto      0.645161
# Name: Number of Open Complaints, dtype: float64

# %% [markdown]
# ### 6. The marketing team wants to analyze the number of policies sold by state and month. Present the data in a table where the months are arranged as columns and the states are arranged as rows.

# %%
df.pivot_table(index='State', columns='Month', values='Number of Policies', aggfunc='sum')
# Out:
# Month       February  January
# State
# Arizona         2864     3052
# California      4929     5673
# Nevada          1278     1493
# Oregon          3969     4697
# Washington      1225     1358

# %% [markdown]
# ### 7. Display a new DataFrame that contains the number of policies sold by month by state for the top 3 states with the highest number of policies sold.
#
# Hint:
#
# To accomplish this, you will first need to group the data by state and month, then count the number of policies sold for each group. Afterwards, you will need to sort the data by the count of policies sold in descending order. Next, you will select the top 3 states with the highest number of policies sold. Finally, you will create a new DataFrame that contains the number of policies sold by month for each of the top 3 states.

# %%
#step1
df.groupby(['State', 'Month']).sum()
# Out:
# C:\Users\ivann\AppData\Local\Temp\ipykernel_10704\2659193208.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['State', 'Month']).sum()
#                      Customer Lifetime Value    Income  Monthly Premium Auto  \
# State      Month
# Arizona    February             7.251232e+06  34593645                 86340
#            January              8.088547e+06  37824274                 91401
# California February             1.310058e+07  60745852                154144
#            January              1.522345e+07  72369538                177829
# Nevada     February             3.658928e+06  17547909                 41818
#            January              4.550630e+06  20612244                 52506
# Oregon     February             1.078118e+07  49270436                125872
#            January              1.291617e+07  59506727                147026
# Washington February             3.175004e+06  16570558                 38453
#            January              3.786721e+06  16846173                 43077
#
#                      Months Since Last Claim  Months Since Policy Inception  \
# State      Month
# Arizona    February                  12554.0                          44769
#            January                   14886.0                          48268
# California February                  23366.0                          78713
#            January                   27138.0                          89556
# Nevada     February                   6067.0                          22034
#            January                    8277.0                          26112
# Oregon     February                  18890.0                          64971
#            January                   22343.0                          76033
# Washington February                   5966.0                          21503
#            January                    7091.0                          22812
#
#                      Number of Open Complaints  Number of Policies  \
# State      Month
# Arizona    February                      273.0                2864
#            January                       414.0                3052
# California February                      616.0                4929
#            January                       659.0                5673
# Nevada     February                      165.0                1278
#            January                       235.0                1493
# Oregon     February                      474.0                3969
#            January                       531.0                4697
# Washington February                      158.0                1225
#            January                       191.0                1358
#
#                      Total Claim Amount
# State      Month
# Arizona    February       391791.809935
#            January        426246.844246
# California February       728908.392577
#            January        835525.621326
# Nevada     February       197186.703856
#            January        242933.263857
# Oregon     February       580750.372129
#            January        681805.589563
# Washington February       184865.322639
#            January        208921.624900

# %%
#step2
df.groupby(['State', 'Month']).size().reset_index(name='Number of Policies')
# Out:
#         State     Month  Number of Policies
# 0     Arizona  February                 929
# 1     Arizona   January                1008
# 2  California  February                1634
# 3  California   January                1918
# 4      Nevada  February                 442
# 5      Nevada   January                 551
# 6      Oregon  February                1344
# 7      Oregon   January                1565
# 8  Washington  February                 425
# 9  Washington   January                 463

# %%
state_policies = df.groupby('State')['Number of Policies'].sum()

# Sort the states by the number of policies sold in descending order
sorted_states = state_policies.sort_values(ascending=False)

# Select the top 3 states with the highest number of policies sold
top_3_states = sorted_states.head(3)

# Print the top 3 states
print(top_3_states)
# Out:
# State
# California    10602
# Oregon         8666
# Arizona        5916
# Name: Number of Policies, dtype: int64
